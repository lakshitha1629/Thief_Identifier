# %%
#Face Recognition with Facebook DeepFace Model
#Author Sefik Ilkin Serengil (sefiks.com)

#-----------------------

import os
from os import listdir
from os.path import isdir
import numpy as np
import cv2
from keras.models import Model, Sequential
from keras.layers import Input, Convolution2D, LocallyConnected2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
from PIL import Image
from keras.preprocessing.image import load_img, save_img, img_to_array
from keras.applications.imagenet_utils import preprocess_input
from keras.preprocessing import image
import matplotlib.pyplot as plt
from keras.models import model_from_json
from numpy import asarray

#-----------------------

target_size = (152, 152)

#-----------------------

#OpenCV haarcascade module

opencv_home = cv2.__file__
folders = opencv_home.split(os.path.sep)[0:-1]
path = folders[0]
for folder in folders[1:]:
	path = path + "/" + folder

detector_path = path+"/data/haarcascade_frontalface_default.xml"

if os.path.isfile(detector_path) != True:
	raise ValueError("Confirm that opencv is installed on your environment! Expected path ",detector_path," violated.")
else:
	face_cascade = cv2.CascadeClassifier(detector_path)

#-------------------------
def detectFace(img_path, target_size=(152, 152)):
	
	img = cv2.imread(img_path)
	
	faces = face_cascade.detectMultiScale(img, 1.3, 5)
	
	if len(faces) > 0:
		x,y,w,h = faces[0]
		
		margin = 0
		x_margin = w * margin / 100
		y_margin = h * margin / 100
		
		if y - y_margin > 0 and y+h+y_margin < img.shape[1] and x-x_margin > 0 and x+w+x_margin < img.shape[0]:
			detected_face = img[int(y-y_margin):int(y+h+y_margin), int(x-x_margin):int(x+w+x_margin)]
		else:
			detected_face = img[int(y):int(y+h), int(x):int(x+w)]
		
		detected_face = cv2.resize(detected_face, target_size)
		
		img_pixels = image.img_to_array(detected_face)
		img_pixels = np.expand_dims(img_pixels, axis = 0)
		
		#normalize in [0, 1]
		img_pixels /= 255 
		
		return img_pixels
	else:
		raise ValueError("Face could not be detected in ", img_path,". Please confirm that the picture is a face photo.")

#-------------------------


#DeepFace model
base_model = Sequential()
base_model.add(Convolution2D(32, (11, 11), activation='relu', name='C1', input_shape=(152, 152, 3)))
base_model.add(MaxPooling2D(pool_size=3, strides=2, padding='same', name='M2'))
base_model.add(Convolution2D(16, (9, 9), activation='relu', name='C3'))
base_model.add(LocallyConnected2D(16, (9, 9), activation='relu', name='L4'))
base_model.add(LocallyConnected2D(16, (7, 7), strides=2, activation='relu', name='L5') )
base_model.add(LocallyConnected2D(16, (5, 5), activation='relu', name='L6'))
base_model.add(Flatten(name='F0'))
base_model.add(Dense(4096, activation='relu', name='F7'))
base_model.add(Dropout(rate=0.5, name='D0'))
base_model.add(Dense(8631, activation='softmax', name='F8'))

base_model.load_weights("weights/VGGFace2_DeepFace_weights_val-0.9034.h5")

#Drop F8 and D0 layers. F7 is the representation layer.
model = Model(inputs=base_model.layers[0].input, outputs=base_model.layers[-3].output)

#------------------------
def l2_normalize(x):
	return x / np.sqrt(np.sum(np.multiply(x, x)))

def sensSMS():
    print("MSG sent")   
    
def findEuclideanDistance(source_representation, test_representation):
	euclidean_distance = source_representation - test_representation
	euclidean_distance = np.sum(np.multiply(euclidean_distance, euclidean_distance))
	euclidean_distance = np.sqrt(euclidean_distance)
	return euclidean_distance

#------------------------	


employee_pictures = "database/"

employees = dict()

for file in listdir(employee_pictures):
	employee, extension = file.split(".")
	img_path = 'database/%s.jpg' % (employee)
	img = detectFace(img_path)
	
	representation = model.predict(img)[0]
	
	employees[employee] = representation
	
print("employee representations retrieved successfully")

#------------------------

cap = cv2.VideoCapture(1) #webcam
criminals=["tasil","Namal","Thisal","Kasun"]
while(True):
	ret, img = cap.read()
	faces = face_cascade.detectMultiScale(img, 1.3, 5)
	
	for (x,y,w,h) in faces:
		if w > 130:
			cv2.rectangle(img, (x,y), (x+w,y+h), (67, 67, 67), 1) 
			
			detected_face = img[int(y):int(y+h), int(x):int(x+w)] 
			detected_face = cv2.resize(detected_face, target_size) 
			
			img_pixels = image.img_to_array(detected_face)
			img_pixels = np.expand_dims(img_pixels, axis = 0)
			img_pixels /= 255
			
			captured_representation = model.predict(img_pixels)[0]
			
			distances = []
			
			for i in employees:
				employee_name = i
				source_representation = employees[i]
				
				distance = findEuclideanDistance(l2_normalize(captured_representation), l2_normalize(source_representation))
				distances.append(distance)
			
			is_found = False; index = 0
			for i in employees:
				employee_name = i
				if index == np.argmin(distances):
					if distances[index] <= 0.70:
						
						print("detected: ",employee_name, "(",distances[index],")")
						employee_name = employee_name.replace("_", "")
						similarity = distances[index]
						
						is_found = True
						
						break
					
				index = index + 1
			
			if is_found:
				display_img = cv2.imread("database/%s.jpg" % employee_name)
				pivot_img_size = 112
				display_img = cv2.resize(display_img, (pivot_img_size, pivot_img_size))
								
                
#                 if employee_name[0:-2] in criminals:
#                     sendSMS()
				try:
					resolution_x = img.shape[1]; resolution_y = img.shape[0]
					
					label = employee_name+" ("+"{0:.2f}".format(similarity)+")"
					
					if y - pivot_img_size > 0 and x + w + pivot_img_size < resolution_x:
						#top right
						img[y - pivot_img_size:y, x+w:x+w+pivot_img_size] = display_img
						cv2.putText(img, label, (x+w, y+10), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (67,67,67), 1)					
						
						#connect face and text
						cv2.line(img,(x+int(w/2), y), (x+3*int(w/4), y-int(pivot_img_size/2)),(67,67,67),1)
						cv2.line(img, (x+3*int(w/4), y-int(pivot_img_size/2)), (x+w, y - int(pivot_img_size/2)), (67,67,67),1)
					elif y + h + pivot_img_size < resolution_y and x - pivot_img_size > 0:
						#bottom left
						img[y+h:y+h+pivot_img_size, x-pivot_img_size:x] = display_img
						cv2.putText(img, label, (x - pivot_img_size, y+h-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (67,67,67), 1)
						
						#connect face and text
						cv2.line(img,(x+int(w/2), y+h), (x+int(w/2)-int(w/4), y+h+int(pivot_img_size/2)),(67,67,67),1)
						cv2.line(img, (x+int(w/2)-int(w/4), y+h+int(pivot_img_size/2)), (x, y+h+int(pivot_img_size/2)), (67,67,67),1)
						
					elif y - pivot_img_size > 0 and x - pivot_img_size > 0:
						#top left
						img[y-pivot_img_size:y, x-pivot_img_size:x] = display_img
						cv2.putText(img, label, (x - pivot_img_size, y+10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (67,67,67), 1)
						
						#connect face and text
						cv2.line(img,(x+int(w/2), y), (x+int(w/2)-int(w/4), y-int(pivot_img_size/2)),(67,67,67),1)
						cv2.line(img, (x+int(w/2)-int(w/4), y-int(pivot_img_size/2)), (x, y - int(pivot_img_size/2)), (67,67,67),1)
						
					elif x+w+pivot_img_size < resolution_x and y + h + pivot_img_size < resolution_y:
						#bottom righ
						img[y+h:y+h+pivot_img_size, x+w:x+w+pivot_img_size] = display_img
						cv2.putText(img, label, (x+w, y+h-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (67,67,67), 1)
						
						#connect face and text
						cv2.line(img,(x+int(w/2), y+h), (x+int(w/2)+int(w/4), y+h+int(pivot_img_size/2)),(67,67,67),1)
						cv2.line(img, (x+int(w/2)+int(w/4), y+h+int(pivot_img_size/2)), (x+w, y+h+int(pivot_img_size/2)), (67,67,67),1)
					
				except Exception as e:
					print("exception occured: ", str(e))
			
	cv2.imshow('img',img)
	
	if cv2.waitKey(1) & 0xFF == ord('q'): 
		break
	
#kill open cv things		
cap.release()
cv2.destroyAllWindows()
# Out:
# employee representations retrieved successfully
# detected:  Nusri4 ( 0.62005407 )
# detected:  Nusri4 ( 0.61300826 )
# detected:  Nusri4 ( 0.6835447 )
# detected:  Nusri4 ( 0.6787472 )
# detected:  Nusri4 ( 0.6657065 )
# detected:  Nusri6 ( 0.69466186 )
# detected:  Nusri6 ( 0.6981416 )
# detected:  Nusri6 ( 0.6969484 )
# detected:  Nusri4 ( 0.69024765 )
# detected:  Nusri4 ( 0.65435886 )
# detected:  Nusri4 ( 0.6686573 )
# detected:  Nusri6 ( 0.6958855 )
# detected:  Nusri4 ( 0.6647241 )
# detected:  Nusri6 ( 0.69531894 )
# detected:  Nusri4 ( 0.6432139 )
# detected:  Nusri6 ( 0.69731796 )
# detected:  Nusri4 ( 0.665141 )
# detected:  Nusri6 ( 0.66930133 )
# detected:  Nusri6 ( 0.66828376 )
# detected:  Nusri6 ( 0.6775414 )
# detected:  Nusri6 ( 0.6808218 )
# detected:  Nusri6 ( 0.6984654 )
# detected:  Nusri6 ( 0.6681757 )
# detected:  Nusri6 ( 0.6846243 )
# detected:  Nusri4 ( 0.66818494 )
# detected:  Nusri4 ( 0.6811409 )
# detected:  Nusri4 ( 0.6560223 )
# detected:  Nusri4 ( 0.6779083 )
# detected:  Nusri4 ( 0.66167253 )
# detected:  Nusri4 ( 0.66477984 )
# detected:  Nusri6 ( 0.6920054 )
# detected:  Nusri6 ( 0.6989533 )
# detected:  Nusri6 ( 0.695413 )
# detected:  Nusri6 ( 0.6596078 )
# detected:  Nusri6 ( 0.6721127 )
# detected:  Nusri6 ( 0.6740754 )
# detected:  Nusri6 ( 0.67171323 )
# detected:  Nusri6 ( 0.68035537 )
# detected:  Nusri6 ( 0.65523726 )
# detected:  Nusri7 ( 0.6934453 )
# detected:  Nusri4 ( 0.6546803 )
# detected:  Nusri6 ( 0.69505763 )
# detected:  Nusri6 ( 0.6780732 )
# detected:  Nusri4 ( 0.6891541 )
# detected:  Nusri4 ( 0.6916115 )
# detected:  Nusri4 ( 0.623994 )
# detected:  Nusri4 ( 0.6721132 )
# detected:  Nusri4 ( 0.65017015 )
# detected:  Nusri4 ( 0.6777636 )
# detected:  Nusri4 ( 0.6229346 )
# detected:  Nusri4 ( 0.6114078 )
# detected:  Nusri4 ( 0.63640165 )
# detected:  Nusri4 ( 0.68676984 )
# detected:  Nusri4 ( 0.6548718 )
# detected:  Nusri4 ( 0.6716953 )
# detected:  Nusri6 ( 0.6909069 )
# detected:  Nusri4 ( 0.64516515 )
# detected:  Nusri6 ( 0.6623372 )
# detected:  Nusri6 ( 0.6585803 )
# detected:  Nusri6 ( 0.6748565 )
# detected:  Nusri6 ( 0.6544932 )
# detected:  Nusri6 ( 0.6788005 )
# detected:  Nusri6 ( 0.6900483 )
# detected:  Nusri4 ( 0.669729 )
# detected:  Nusri4 ( 0.6381567 )
# detected:  Nusri4 ( 0.62823415 )
# detected:  Nusri6 ( 0.66142064 )
# detected:  Nusri4 ( 0.636058 )
# detected:  Nusri4 ( 0.6305946 )
# detected:  Nusri6 ( 0.6778979 )
# detected:  Nusri6 ( 0.6792543 )
# detected:  Nusri4 ( 0.67886513 )
# detected:  Nusri4 ( 0.6767432 )
# detected:  Nusri4 ( 0.64803815 )
# detected:  Nusri6 ( 0.6821794 )
# detected:  Nusri6 ( 0.6823251 )
# detected:  Nusri6 ( 0.6970766 )
# detected:  Nusri6 ( 0.6917979 )
# detected:  Nusri6 ( 0.6840281 )
# detected:  Nusri4 ( 0.69393814 )
# detected:  Nusri6 ( 0.6964194 )
# detected:  Nusri4 ( 0.6842072 )
# detected:  Nusri4 ( 0.6978139 )
# detected:  Nusri6 ( 0.68474007 )
# detected:  Nusri6 ( 0.69086635 )
# detected:  Nusri6 ( 0.68827385 )
# detected:  Nusri6 ( 0.6817274 )
# detected:  Nusri4 ( 0.6491113 )
# detected:  Nusri6 ( 0.6913878 )
# detected:  Nusri6 ( 0.6992276 )
# detected:  Nusri6 ( 0.68058527 )
# detected:  Nusri4 ( 0.69476783 )
# detected:  Nusri6 ( 0.69044095 )
# detected:  Nusri6 ( 0.67263746 )
# detected:  Nusri6 ( 0.67705214 )
# detected:  Nusri4 ( 0.6880046 )
# detected:  Nusri6 ( 0.68263996 )
# detected:  Nusri6 ( 0.6925004 )
# detected:  Nusri6 ( 0.68414617 )
# detected:  Nusri6 ( 0.6797886 )
# detected:  Nusri6 ( 0.6763912 )
# detected:  Nusri6 ( 0.6990771 )
# detected:  Nusri6 ( 0.6679984 )
# detected:  Nusri6 ( 0.6577523 )
# detected:  Nusri6 ( 0.680525 )
# detected:  Nusri6 ( 0.68605256 )
# detected:  Nusri6 ( 0.6760899 )
# detected:  Nusri6 ( 0.66949373 )
# detected:  Nusri6 ( 0.6612081 )
# detected:  Nusri6 ( 0.68573135 )
# detected:  Nusri6 ( 0.69749457 )
# detected:  Nusri6 ( 0.6718914 )
# detected:  Nusri6 ( 0.6685404 )
# detected:  Nusri6 ( 0.6626266 )
# detected:  Nusri6 ( 0.6596622 )
# detected:  Nusri6 ( 0.6703356 )
# detected:  Nusri6 ( 0.6777998 )
# detected:  Nusri6 ( 0.6585461 )
# detected:  Nusri6 ( 0.6679326 )
# detected:  Nusri4 ( 0.6333362 )
# detected:  Nusri6 ( 0.6843346 )
# detected:  Nusri4 ( 0.67766166 )
# detected:  Nusri4 ( 0.6495881 )
# detected:  Nusri6 ( 0.68377244 )
# detected:  Nusri6 ( 0.68268037 )
# detected:  Nusri6 ( 0.6688231 )
# detected:  Nusri4 ( 0.6355271 )
# detected:  Nusri6 ( 0.6672872 )
# detected:  Nusri4 ( 0.61974007 )
# detected:  Nusri6 ( 0.68710613 )
# detected:  Nusri6 ( 0.6670149 )
# detected:  Nusri6 ( 0.67874265 )
# detected:  Nusri6 ( 0.6884465 )
# detected:  Nusri6 ( 0.69405097 )
# detected:  Nusri6 ( 0.6702519 )
# detected:  Nusri6 ( 0.680005 )
# detected:  Nusri4 ( 0.69105285 )
# detected:  Nusri4 ( 0.68582374 )
# detected:  Nusri6 ( 0.69519 )
# detected:  Nusri4 ( 0.6669111 )
# detected:  Nusri6 ( 0.6844862 )
# detected:  Nusri4 ( 0.6763112 )
# detected:  Nusri4 ( 0.6780019 )
# detected:  Nusri6 ( 0.69175684 )
# detected:  Nusri6 ( 0.6867157 )
# detected:  Nusri6 ( 0.6872679 )
# detected:  Nusri6 ( 0.68588823 )
# detected:  Nusri6 ( 0.69282347 )
# detected:  Nusri4 ( 0.6781222 )
# detected:  Nusri4 ( 0.6884787 )
# detected:  Nusri6 ( 0.695545 )
# detected:  Nusri6 ( 0.68583983 )
# detected:  Nusri6 ( 0.697736 )
# detected:  Nusri4 ( 0.6806131 )
# detected:  Nusri4 ( 0.6979405 )
# detected:  Nusri4 ( 0.6656044 )
# detected:  Nusri4 ( 0.6726482 )
# detected:  Nusri4 ( 0.6592007 )
# detected:  Nusri4 ( 0.6625118 )
# detected:  Nusri4 ( 0.68596816 )
# detected:  Nusri6 ( 0.6809717 )
# detected:  Nusri6 ( 0.6904279 )
# detected:  Nusri4 ( 0.6812769 )
# detected:  Nusri6 ( 0.69214284 )
# detected:  Nusri4 ( 0.68215144 )
# detected:  Nusri6 ( 0.6959952 )
# detected:  Nusri6 ( 0.68855494 )
# detected:  Nusri4 ( 0.69183046 )
# detected:  Nusri4 ( 0.67222995 )
# detected:  Nusri4 ( 0.6715249 )
# detected:  Nusri4 ( 0.6429922 )
# detected:  Nusri4 ( 0.57296664 )
# detected:  Nusri4 ( 0.6169517 )
# detected:  Nusri4 ( 0.6275967 )
# detected:  Nusri4 ( 0.5920347 )
# detected:  Nusri4 ( 0.5965866 )
# detected:  Nusri4 ( 0.62762755 )
# detected:  Nusri4 ( 0.5860636 )
# detected:  Nusri4 ( 0.6657475 )
# detected:  Nusri4 ( 0.57431465 )
# detected:  Nusri4 ( 0.67818815 )
# detected:  Nusri4 ( 0.5870714 )
# detected:  Nusri4 ( 0.6514396 )
# detected:  Nusri4 ( 0.5810372 )
# detected:  Nusri4 ( 0.6327361 )
# detected:  Nusri4 ( 0.61207026 )
# detected:  Nusri4 ( 0.6256531 )
# detected:  Nusri4 ( 0.616402 )
# detected:  Nusri4 ( 0.56764793 )
# detected:  Nusri4 ( 0.59692556 )
# detected:  Nusri4 ( 0.5968546 )
# detected:  Nusri4 ( 0.58983445 )
# detected:  Nusri4 ( 0.69969016 )
# detected:  Nusri4 ( 0.6640963 )
# detected:  Nusri4 ( 0.69842845 )
# detected:  Nusri4 ( 0.69894075 )
# detected:  Nusri4 ( 0.65404445 )
# detected:  Nusri4 ( 0.65498257 )
# detected:  Nusri4 ( 0.6935737 )
# detected:  Nusri4 ( 0.66138095 )
# detected:  Nusri4 ( 0.6679283 )
# detected:  Nusri4 ( 0.6558186 )
# detected:  Nusri4 ( 0.6383737 )
# detected:  Nusri4 ( 0.6688291 )
# detected:  Nusri4 ( 0.6698232 )
# detected:  Nusri4 ( 0.6513969 )
# detected:  Nusri4 ( 0.6472218 )
# detected:  Nusri4 ( 0.667022 )
# detected:  Nusri4 ( 0.69439733 )
# detected:  Nusri4 ( 0.66012746 )
# detected:  Nusri4 ( 0.6842912 )
# detected:  Nusri4 ( 0.66182804 )
# detected:  Nusri4 ( 0.6881183 )
# detected:  Nusri4 ( 0.67627174 )
# detected:  Nusri4 ( 0.69777715 )
# detected:  Nusri4 ( 0.6850812 )
# detected:  Nusri4 ( 0.66272503 )
# detected:  Nusri4 ( 0.69750375 )
# detected:  Nusri4 ( 0.67691493 )
# detected:  Nusri1 ( 0.69975 )
# detected:  Nusri4 ( 0.6375344 )
# detected:  Nusri4 ( 0.6606424 )
# detected:  Nusri4 ( 0.69985104 )
# detected:  Nusri6 ( 0.6930172 )
# detected:  Nusri7 ( 0.67806524 )
# detected:  Nusri6 ( 0.6817553 )
# detected:  Nusri6 ( 0.6863093 )
# detected:  Nusri6 ( 0.67196655 )
# detected:  Nusri6 ( 0.69680834 )
# detected:  Nusri4 ( 0.67831194 )
# detected:  Nusri7 ( 0.6968506 )
# detected:  Nusri4 ( 0.63757133 )
# detected:  Nusri4 ( 0.6586855 )
# detected:  Nusri4 ( 0.6874801 )
# detected:  Nusri4 ( 0.6863301 )
# detected:  Nusri4 ( 0.67472154 )
# detected:  Nusri4 ( 0.6867813 )
# detected:  Nusri4 ( 0.6858043 )
# detected:  Nusri6 ( 0.6925492 )
# detected:  Nusri6 ( 0.6979888 )
# detected:  Nusri4 ( 0.682098 )
# detected:  Nusri4 ( 0.6486241 )
# detected:  Nusri4 ( 0.69859904 )
# detected:  Nusri4 ( 0.6764698 )
# detected:  Nusri4 ( 0.6413008 )
# detected:  Nusri4 ( 0.6975201 )
# detected:  Nusri4 ( 0.6261659 )
# detected:  Nusri6 ( 0.69899726 )
# detected:  Nusri4 ( 0.6663002 )
# detected:  Nusri4 ( 0.6405988 )
# detected:  Nusri4 ( 0.64417106 )
# detected:  Nusri4 ( 0.6795848 )
# detected:  Nusri4 ( 0.6737191 )
# detected:  Nusri6 ( 0.6944704 )
